# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("cars.csv")

# %%
df.head()
# Out:
#   First Name   Last Name         Country Car Brand     Car Model Car Color  \
# 0      Yetty     Arghent       Indonesia      Ford    Club Wagon      Teal
# 1    Crystal    Bosworth           China  Cadillac  Escalade ESV    Fuscia
# 2      Monro    Houdhury       Indonesia     Mazda    Miata MX-5    Orange
# 3      Bowie       Clair           China      Audi            A4    Orange
# 4     Myrvyn  McAllister  Czech Republic    Nissan        Maxima      Pink
#
#    Year of Manufacture Credit Card Type
# 0                 1993       mastercard
# 1                 2007       mastercard
# 2                 2009          maestro
# 3                 2005     instapayment
# 4                 1994          maestro

# %%
df.shape
# Out:
# (30000, 8)

# %%
df.isna().sum()
# Out:
# First Name             0
# Last Name              0
# Country                0
# Car Brand              0
# Car Model              0
# Car Color              0
# Year of Manufacture    0
# Credit Card Type       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   First Name           30000 non-null  object
#  1   Last Name            30000 non-null  object
#  2   Country              30000 non-null  object
#  3   Car Brand            30000 non-null  object
#  4   Car Model            30000 non-null  object
#  5   Car Color            30000 non-null  object
#  6   Year of Manufacture  30000 non-null  int64
#  7   Credit Card Type     30000 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.8+ MB

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)
df.columns
# Out:
# Index(['first_name', 'last_name', 'country', 'car_brand', 'car_model',
#        'car_color', 'year_of_manufacture', 'credit_card_type'],
#       dtype='object')

# %%
df_ml = df.drop(columns=["first_name", "last_name"])

# %%
categorical_cols = df.select_dtypes(include="object").columns

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df["year_of_manufacture"].fillna(
    df["year_of_manufacture"].median(),
    inplace=True
)

# %%
df = df.drop_duplicates()

# %%
df = df[
    (df["year_of_manufacture"] >= 1980) &
    (df["year_of_manufacture"] <= 2025)
]

# %%
for col in categorical_cols:
    df[col] = df[col].str.strip().str.lower()

# %%
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              30000 non-null  object
#  1   car_brand            30000 non-null  object
#  2   car_model            30000 non-null  object
#  3   car_color            30000 non-null  object
#  4   year_of_manufacture  30000 non-null  int64
#  5   credit_card_type     30000 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.4+ MB

# %%
df_ml.head()
# Out:
#           country car_brand     car_model car_color  year_of_manufacture  \
# 0       Indonesia      Ford    Club Wagon      Teal                 1993
# 1           China  Cadillac  Escalade ESV    Fuscia                 2007
# 2       Indonesia     Mazda    Miata MX-5    Orange                 2009
# 3           China      Audi            A4    Orange                 2005
# 4  Czech Republic    Nissan        Maxima      Pink                 1994
#
#   credit_card_type
# 0       mastercard
# 1       mastercard
# 2          maestro
# 3     instapayment
# 4          maestro

# %%
TARGET = "car_brand"

FEATURES = [
    "country",
    "car_model",
    "car_color",
    "year_of_manufacture",
    "credit_card_type"
]

# %%
# Top 5 car brands
df_ml["car_brand"].value_counts().head(5)
# Out:
# car_brand
# Ford         2562
# Chevrolet    2487
# Toyota       1445
# Dodge        1438
# GMC          1296
# Name: count, dtype: int64

# %%
# Country-wise car distribution
df_ml["country"].value_counts().head(10)
# Out:
# country
# China            5465
# Indonesia        3163
# Russia           1671
# Philippines      1636
# Brazil           1196
# Poland           1039
# Portugal          987
# France            854
# Sweden            778
# United States     633
# Name: count, dtype: int64

# %%
# Year-wise distribution
df_ml["year_of_manufacture"].value_counts().sort_index()
# Out:
# year_of_manufacture
# 1909       1
# 1926       4
# 1948       5
# 1950       1
# 1953       6
#         ...
# 2009    1572
# 2010    1382
# 2011    1341
# 2012    1405
# 2013     242
# Name: count, Length: 65, dtype: int64

# %%
df_ml.to_csv("cars_cleaned.csv", index=False)

# %% [raw]
# Load the cleaned data

# %%
import pandas as pd

df = pd.read_csv("cars_cleaned.csv")

# %%
df.head()
# Out:
#           country car_brand     car_model car_color  year_of_manufacture  \
# 0       Indonesia      Ford    Club Wagon      Teal                 1993
# 1           China  Cadillac  Escalade ESV    Fuscia                 2007
# 2       Indonesia     Mazda    Miata MX-5    Orange                 2009
# 3           China      Audi            A4    Orange                 2005
# 4  Czech Republic    Nissan        Maxima      Pink                 1994
#
#   credit_card_type
# 0       mastercard
# 1       mastercard
# 2          maestro
# 3     instapayment
# 4          maestro

# %% [raw]
# Separate features and target

# %%
TARGET = "car_brand"

FEATURES = [
    "country",
    "car_model",
    "car_color",
    "year_of_manufacture",
    "credit_card_type"
]

X = df[FEATURES]
y = df[TARGET]

# %% [raw]
# Encode categorical features

# %%
# Re-encode categorical features
label_encoders = {}
X_encoded = X.copy()

from sklearn.preprocessing import LabelEncoder

for col in X_encoded.select_dtypes(include="object").columns:
    le = LabelEncoder()
    X_encoded[col] = le.fit_transform(X_encoded[col])
    label_encoders[col] = le

# %%
# Encode target
target_encoder = LabelEncoder()
y_encoded = target_encoder.fit_transform(y)
label_encoders["car_brand"] = target_encoder

# %% [raw]
# Train–test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y_encoded,
    test_size=0.2,
    random_state=42
)

# %% [raw]
# Train the model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)

# %% [raw]
# Evaluate the model

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7146666666666667
#               precision    recall  f1-score   support
#
#            0       0.79      0.65      0.71       105
#            1       1.00      0.56      0.71         9
#            2       0.00      0.00      0.00         1
#            3       0.71      0.59      0.64        49
#            4       0.84      0.79      0.81       167
#            5       1.00      1.00      1.00         1
#            6       0.89      0.91      0.90       192
#            7       0.76      0.66      0.70        38
#            9       0.70      0.67      0.68       140
#           10       0.83      0.76      0.79        99
#           11       0.62      0.84      0.72       484
#           12       0.51      0.46      0.48       106
#           13       1.00      0.40      0.57         5
#           14       0.00      0.00      0.00         2
#           15       0.17      0.12      0.14         8
#           16       0.00      0.00      0.00         2
#           17       0.81      0.75      0.78       312
#           18       0.40      0.38      0.39        21
#           20       0.00      0.00      0.00         6
#           22       1.00      1.00      1.00         3
#           23       0.00      0.00      0.00         0
#           24       0.72      0.86      0.78       510
#           25       0.73      0.82      0.77       257
#           26       0.44      0.47      0.45        15
#           28       0.00      0.00      0.00         3
#           29       0.66      0.58      0.62       157
#           30       0.88      0.88      0.88        33
#           31       0.73      0.58      0.64       116
#           32       0.76      0.68      0.72        81
#           33       0.57      0.47      0.51        62
#           34       0.74      0.89      0.81        45
#           35       0.83      0.61      0.70        74
#           36       0.00      0.00      0.00         1
#           37       0.72      0.59      0.65        99
#           38       0.62      0.44      0.52        34
#           39       0.94      0.86      0.90        72
#           40       0.67      0.76      0.72       144
#           41       0.69      0.71      0.70       103
#           42       0.68      0.56      0.61        34
#           43       1.00      1.00      1.00         2
#           44       0.65      0.79      0.71        19
#           45       0.64      0.27      0.38        33
#           46       0.79      0.58      0.67        19
#           47       0.77      0.80      0.78       215
#           48       0.00      0.00      0.00         5
#           49       0.77      0.89      0.82       219
#           50       0.65      0.71      0.67       119
#           51       0.00      0.00      0.00         1
#           52       0.70      0.64      0.67       239
#           53       1.00      1.00      1.00         1
#           54       0.59      0.56      0.57       169
#           55       0.60      0.51      0.55        70
#           56       0.00      0.00      0.00         2
#           57       1.00      1.00      1.00         1
#           58       0.51      0.50      0.50        52
#           59       0.78      0.75      0.77       194
#           60       0.82      0.77      0.79        73
#           61       0.80      1.00      0.89         4
#           63       0.00      0.00      0.00         1
#           64       0.40      0.40      0.40         5
#           65       1.00      1.00      1.00        55
#           66       0.72      0.47      0.57        45
#           67       1.00      1.00      1.00        19
#           68       0.00      0.00      0.00         2
#           69       1.00      0.80      0.89         5
#           70       1.00      0.17      0.29         6
#           71       1.00      1.00      1.00         3
#           72       0.63      0.53      0.58       118
#           73       0.70      0.59      0.64       103
#           74       0.50      1.00      0.67         2
#           75       0.69      0.61      0.65       307
#           76       0.61      0.59      0.60       186
#           77       0.70      0.81      0.75       116
#
#     accuracy                           0.71      6000
#    macro avg       0.62      0.58      0.59      6000
# weighted avg       0.71      0.71      0.71      6000

# %% [raw]
# Save model and encoders

# %%
import os

os.makedirs("../model", exist_ok=True)

# Save model
with open("../model/car_brand_model.pkl", "wb") as f:
    pickle.dump(model, f)

# Save encoders
with open("../model/label_encoders.pkl", "wb") as f:
    pickle.dump(label_encoders, f)

print("✅ Model and encoders saved successfully")
# Out:
# ✅ Model and encoders saved successfully
